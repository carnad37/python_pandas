# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
s = pd.Series(np.random.randn(10).cumsum(), index = np.arange(0, 100, 10))
s.plot()
print(s)
#plt.show() - 다른 IDE에선 필요
# Out:
# 0    -1.303355
# 10   -0.553076
# 20   -0.970439
# 30   -1.581312
# 40   -0.785320
# 50    0.078967
# 60    1.096404
# 70    1.464017
# 80    1.009904
# 90    2.093070
# dtype: float64

# %%
df = pd.read_csv("edu_age_earn.csv")
df.head(10)
# Out:
#            earn  ed  age
# 0  79571.299010  16   49
# 1  96396.988640  16   62
# 2  48710.666950  16   33
# 3  80478.096150  16   95
# 4  82089.345500  17   43
# 5  15313.352900  15   30
# 6  47104.171820  12   53
# 7  50960.054280  17   50
# 8   3212.649556  15   25
# 9  42996.637880  12   30

# %%
df.drop('earn', axis=1, inplace=True)
df.plot()

# %%
df['ed'].plot()

# %%
df = pd.read_csv("regression.csv")

# %%
df.plot()
df.plot(kind='bar')

# %%
df.height.plot(kind='bar')

# %%
df.plot(kind='bar', stacked=True)

# %%
df2 = pd.DataFrame(np.random.rand(6,4), index=["one", "two", "three", "four", "five", "six"])
df2.plot(kind='barh', stacked=True)

# %%
s3 = pd.Series(np.random.normal(0, 1, 200))
s3.hist() #겹치는 값들을 표시

# %%
s3.hist(bins=50)

# %%
s3.hist(bins=100, normed=True) #각 bin에 속하는 개수를 전체 개수로 나눈 비율, 정규화 한 값을 bar의 높이로 사용
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
x1 = np.random.normal(1, 1, size=(100,1))
x1 = map(lambda x: x[0], x1)
x1 = pd.Series(x1, index=range(1,101))

# %%
x1.plot()

# %%
a = np.array([[1, 2], [3, 4]])
b = np.array([[5, 6], [7, 8]])
c = np.concatenate((a, b), axis = 1)
c
# Out:
# array([[1, 2, 5, 6],
#        [3, 4, 7, 8]])

# %%
x1 = np.random.normal(1, 1, size=(100,1))
x2 = np.random.normal(1, 1, size=(100,1))
x3 = np.concatenate((x1,x2), axis=1)
df3 = pd.DataFrame(x3, columns=["x1", "x2"])
plt.scatter(df3.x1, df3.x2)
