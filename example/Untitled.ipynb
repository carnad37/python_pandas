# %%
import numpy as np
import pandas as pd
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv("./dataset/iris.csv")
df.head(10)
# Out:
#    caseno  SepalLength  SepalWidth  PetalLength  PetalWidth Species
# 0       1          5.1         3.5          1.4         0.2  setosa
# 1       2          4.9         3.0          1.4         0.2  setosa
# 2       3          4.7         3.2          1.3         0.2  setosa
# 3       4          4.6         3.1          1.5         0.2  setosa
# 4       5          5.0         3.6          1.4         0.2  setosa
# 5       6          5.4         3.9          1.7         0.4  setosa
# 6       7          4.6         3.4          1.4         0.3  setosa
# 7       8          5.0         3.4          1.5         0.2  setosa
# 8       9          4.4         2.9          1.4         0.2  setosa
# 9      10          4.9         3.1          1.5         0.1  setosa

# %%
df.Species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.Species.replace(['setosa', "versicolor", "virginica"], [1, 2, 3], inplace=True)

# %%
clf = GaussianNB()
array = df.values
X = array[:, 1:5]
Y = array[:, 5]

validation_size = 0.33
seed = 7
X_train, X_validation, Y_train, Y_validation = train_test_split(X, Y, test_size=validation_size, random_state=seed)

scoring = 'accuracy'

clf.fit(X_train, Y_train)

pred_clf = clf.predict(X_validation)

prob_pos_clf = clf.predict_proba(X_validation)[:, 1]
print(prob_pos_clf)
# Out:
# [2.55970017e-02 9.94743400e-01 1.04094333e-17 9.92960029e-01
#  9.83133501e-01 6.49187445e-15 3.73700413e-01 9.99941349e-01
#  1.17389209e-17 9.28258179e-01 3.65749690e-02 7.81290905e-01
#  1.19821334e-21 3.32428395e-15 3.66428522e-18 5.82568059e-02
#  2.85289468e-04 6.28632947e-04 9.33229545e-19 1.66151772e-20
#  9.99990875e-01 2.06019866e-10 9.91183239e-01 9.83703907e-01
#  3.96279970e-04 9.06382283e-02 9.99444506e-01 9.99999304e-01
#  1.06479432e-02 5.57376556e-11 1.07677068e-01 9.99999696e-01
#  4.46361697e-20 3.32826288e-07 9.99079180e-01 5.09735221e-16
#  2.84786339e-18 7.11119225e-15 3.02078150e-17 1.15296954e-08
#  5.32665967e-08 9.33513112e-01 9.63556655e-08 6.70206490e-04
#  9.99934547e-01 3.99331208e-18 9.79169998e-01 9.99998886e-01
#  9.29543990e-04 4.26630142e-17]

# %%
pred_clf_df = pd.DataFrame(pred_clf.reshape(50,1))
pred_clf_df.rename(columns = {0:'Prediction'}, inplace=True)

X_validation_df = pd.DataFrame(X_validation, columns=['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth'])
X_validation_df
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth
# 0           5.9         3.0          5.1         1.8
# 1           5.4         3.0          4.5         1.5
# 2           5.0         3.5          1.3         0.3
# 3           5.6         3.0          4.5         1.5
# 4           4.9         2.5          4.5         1.7
# 5           4.5         2.3          1.3         0.3
# 6           6.9         3.1          4.9         1.5
# 7           5.6         2.7          4.2         1.3
# 8           4.8         3.4          1.6         0.2
# 9           6.4         3.2          4.5         1.5
# 10          6.7         3.0          5.0         1.7
# 11          6.0         3.4          4.5         1.6
# 12          5.2         4.1          1.5         0.1
# 13          7.2         3.6          6.1         2.5
# 14          5.2         3.4          1.4         0.2
# 15          5.9         3.2          4.8         1.8
# 16          6.7         2.5          5.8         1.8
# ...

# %%
pred_outcome = pd.concat([X_validation_df, pred_clf_df], axis=1, join_axes=[X_validation_df.index])
pred_outcome.head(10)
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Prediction
# 0          5.9         3.0          5.1         1.8         3.0
# 1          5.4         3.0          4.5         1.5         2.0
# 2          5.0         3.5          1.3         0.3         1.0
# 3          5.6         3.0          4.5         1.5         2.0
# 4          4.9         2.5          4.5         1.7         2.0
# 5          4.5         2.3          1.3         0.3         1.0
# 6          6.9         3.1          4.9         1.5         3.0
# 7          5.6         2.7          4.2         1.3         2.0
# 8          4.8         3.4          1.6         0.2         1.0
# 9          6.4         3.2          4.5         1.5         2.0

# %%
del df['caseno']

# %%
# pred_comp=pred_outcome

# %%
pred_comp = pd.merge(df, pred_outcome, on = ['SepalLength', 'SepalWidth', 'PetalLength', 'PetalWidth'])
print(pred_comp.head(10))
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth  Species  Prediction
# 0          5.4         3.9          1.7         0.4        1         1.0
# 1          4.8         3.4          1.6         0.2        1         1.0
# 2          5.1         3.5          1.4         0.3        1         1.0
# 3          4.6         3.6          1.0         0.2        1         1.0
# 4          5.2         3.4          1.4         0.2        1         1.0
# 5          4.7         3.2          1.6         0.2        1         1.0
# 6          5.2         4.1          1.5         0.1        1         1.0
# 7          5.5         3.5          1.3         0.2        1         1.0
# 8          4.9         3.6          1.4         0.1        1         1.0
# 9          5.0         3.5          1.3         0.3        1         1.0

# %%
import matplotlib.pyplot as plt

plt.scatter(pred_comp['SepalLength'], pred_comp.SepalWidth, c = pred_comp.Species, alpha = 0.5)
plt.show()
