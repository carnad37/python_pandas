# %%
import pandas as pd

# %%
mp_data = pd.read_csv('./milk.csv', encoding = "CP949")
mp_df = pd.DataFrame(mp_data, columns=["년도", "유제품별", "생산량", "소비량"])
mp_df.rename(columns={"년도":"year", "유제품별" : "product", "생산량" : "product_rate", "소비량" : "consumption"}, inplace=True)
mp_df
# Out:
#        년도  유제품별      생산량      소비량
# 0    2015    치즈    23188   103899
# 1    2015    버터     3587    10206
# 2    2015   발효유   596928   589768
# 3    2015  백색시유  1345440  1345440
# 4    2015  가공시유   302046   302046
# 5    2015  조제분유    22183    16583
# 6    2015  전지분유     2615     4050
# 7    2015  탈지분유    17076    19742
# 8    2015    연유     8079     4593
# 9    2014  백색시유  1356301  1356301
# 10   2014    치즈    23779   117829
# 11   2014    버터     4311     9185
# 12   2014    연유     8535     2732
# 13   2014   발효유   572418   567069
# 14   2014  전지분유     2784     4178
# 15   2014  조제분유    17991    13555
# 16   2014  가공시유   280693   280693
# 17   2014  탈지분유    21395    32029
# 18   2013    치즈    22389   107558
# 19   2013    버터     2003     7950
# 20   2013    연유     6012     1069
# 21   2013  탈지분유    11670    31422
# 22   2013  전지분유     1912     4031
# 23   2013  조제분유    17541    13737
# 24   2013  가공시유   291307   291307
# 25   2013  백색시유  1392204  1392204
# ...

# %%
#버터의 생산량이 가장 많았던 연도와 생산량
