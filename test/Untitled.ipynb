# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import MinMaxScaler
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, random_state=0)

# %%
scaler = MinMaxScaler().fit(X_train)

# %%
from sklearn.model_selection import GridSearchCV
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

grid_list = [0.001, 0.01, 0.1, 1, 10, 100]
param_grid = {'C':grid_list, 'gamma':grid_list}

grid = GridSearchCV(SVC(), param_grid=param_grid, cv=5)
grid.fit(X_train_scaled, y_train)
print("최상의 교차 검증 정확도: {:.2f}".format(grid.best_score_))
print("테스트 점수: {:.2f}".format(grid.score(X_test_scaled, y_test)))
print("최적의 매개변수: ", grid.best_params_)
# Out:
# 최상의 교차 검증 정확도: 0.98
# 테스트 점수: 0.97
# 최적의 매개변수:  {'C': 1, 'gamma': 1}

# %%
from sklearn.pipeline import Pipeline
pipe = Pipeline([("scaler",MinMaxScaler()), ("svm",SVC())])
pipe.fit(X_train, y_train)

grid_list = [0.001, 0.01, 0.1, 1, 10, 100]
param_grid = {'svm__C':grid_list, 'svm__gamma':grid_list}

grid = GridSearchCV(pipe, param_grid=param_grid, cv = 5)
grid.fit(X_train, y_train)
print("최상의 교차 검증 정확도: {:.2f}".format(grid.best_score_))
print("테스트 점수: {:.2f}".format(grid.score(X_test_scaled, y_test)))
print("최적의 매개변수: ", grid.best_params_)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 최상의 교차 검증 정확도: 0.98
# 테스트 점수: 0.37
# 최적의 매개변수:  {'svm__C': 1, 'svm__gamma': 1}

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier

pipe = Pipeline([('preprocessing', StandardScaler()),('classifier', SVC())])

param_grid = [
    {'classifier' : [SVC()], 'preprocessing' : [StandardScaler(), MinMaxScaler()],
     'classifier__gamma' : grid_list, 'classifier__C' : grid_list}]

grid = GridSearchCV(pipe, param_grid=param_grid, cv=5)
grid.fit(X_train, y_train)

print("최적의 매개변수:\n{}\n".format(grid.best_params_))
print("최상의 교차 검증 점수: {:.2f}".format(grid.best_score_))
print("테스트 세트 점수: {:.2f}".format(grid.score(X_test, y_test)))
# Out:
# 최적의 매개변수:
# {'classifier': SVC(C=10, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=0.01, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False), 'classifier__C': 10, 'classifier__gamma': 0.01, 'preprocessing': StandardScaler(copy=True, with_mean=True, with_std=True)}
#
# 최상의 교차 검증 점수: 0.99
# 테스트 세트 점수: 0.98

# %%
import pandas as pd

param_grid = [{'kernel' : ['rbf'],
               'C' : grid_list, 'gamma' :grid_list},
             {'kernel' : ['linear'],
              'C' : grid_list}]
grid_search = GridSearchCV(SVC(), param_grid=param_grid, cv=5, return_train_score=True)
grid_search.fit(X_train, y_train)
print("최적의 파라미터 :", grid_search.best_params_)
print("최고 교차 검증 점수 : {:.2f}".format(grid_search.best_score_))
results = pd.DataFrame(grid_search.cv_results_)
display(results.T)
# Out:
# 최적의 파라미터 : {'C': 1, 'kernel': 'linear'}
# 최고 교차 검증 점수 : 0.96
#                                                                0   \
# mean_fit_time                                           0.0105999
# std_fit_time                                           0.00307245
# mean_score_time                                        0.00240002
# std_score_time                                         0.00101984
# param_C                                                     0.001
# param_gamma                                                 0.001
# param_kernel                                                  rbf
# params              {'C': 0.001, 'gamma': 0.001, 'kernel': 'rbf'}
# split0_test_score                                        0.627907
# split1_test_score                                        0.627907
# split2_test_score                                        0.623529
# split3_test_score                                        0.623529
# split4_test_score                                        0.630952
# mean_test_score                                          0.626761
# std_test_score                                         0.00285688
# rank_test_score                                                12
# split0_train_score                                       0.626471
# split1_train_score                                       0.626471
# split2_train_score                                       0.627566
# split3_train_score                                       0.627566
# split4_train_score                                       0.625731
# mean_train_score                                         0.626761
# std_train_score                                       0.000710716
#
#                                                               1   \
# mean_fit_time                                             0.0092
# std_fit_time                                         0.000748417
# mean_score_time                                       0.00199995
# std_score_time                                       1.16801e-07
# param_C                                                    0.001
# param_gamma                                                 0.01
# param_kernel                                                 rbf
# params              {'C': 0.001, 'gamma': 0.01, 'kernel': 'rbf'}
# split0_test_score                                       0.627907
# split1_test_score                                       0.627907
# split2_test_score                                       0.623529
# split3_test_score                                       0.623529
# split4_test_score                                       0.630952
# mean_test_score                                         0.626761
# std_test_score                                        0.00285688
# rank_test_score                                               12
# split0_train_score                                      0.626471
# split1_train_score                                      0.626471
# split2_train_score                                      0.627566
# split3_train_score                                      0.627566
# split4_train_score                                      0.625731
# mean_train_score                                        0.626761
# std_train_score                                      0.000710716
#
#                                                              2   \
# mean_fit_time                                        0.00859995
# std_fit_time                                        0.000800049
# mean_score_time                                      0.00219994
# std_score_time                                      0.000399923
# param_C                                                   0.001
# param_gamma                                                 0.1
# param_kernel                                                rbf
# params              {'C': 0.001, 'gamma': 0.1, 'kernel': 'rbf'}
# split0_test_score                                      0.627907
# split1_test_score                                      0.627907
# split2_test_score                                      0.623529
# split3_test_score                                      0.623529
# split4_test_score                                      0.630952
# mean_test_score                                        0.626761
# std_test_score                                       0.00285688
# rank_test_score                                              12
# split0_train_score                                     0.626471
# split1_train_score                                     0.626471
# split2_train_score                                     0.627566
# split3_train_score                                     0.627566
# split4_train_score                                     0.625731
# mean_train_score                                       0.626761
# std_train_score                                     0.000710716
#
#                                                            3   \
# mean_fit_time                                      0.00999994
# std_fit_time                                      1.78416e-07
# mean_score_time                                    0.00300002
# std_score_time                                    1.50789e-07
# param_C                                                 0.001
# param_gamma                                                 1
# param_kernel                                              rbf
# params              {'C': 0.001, 'gamma': 1, 'kernel': 'rbf'}
# split0_test_score                                    0.627907
# split1_test_score                                    0.627907
# split2_test_score                                    0.623529
# split3_test_score                                    0.623529
# split4_test_score                                    0.630952
# mean_test_score                                      0.626761
# std_test_score                                     0.00285688
# rank_test_score                                            12
# split0_train_score                                   0.626471
# split1_train_score                                   0.626471
# split2_train_score                                   0.627566
# split3_train_score                                   0.627566
# split4_train_score                                   0.625731
# mean_train_score                                     0.626761
# std_train_score                                   0.000710716
#
#                                                             4   \
# mean_fit_time                                        0.0105999
# std_fit_time                                        0.00048996
# mean_score_time                                     0.00260005
# std_score_time                                     0.000489862
# param_C                                                  0.001
# param_gamma                                                 10
# param_kernel                                               rbf
# params              {'C': 0.001, 'gamma': 10, 'kernel': 'rbf'}
# split0_test_score                                     0.627907
# split1_test_score                                     0.627907
# split2_test_score                                     0.623529
# split3_test_score                                     0.623529
# split4_test_score                                     0.630952
# mean_test_score                                       0.626761
# std_test_score                                      0.00285688
# rank_test_score                                             12
# split0_train_score                                    0.626471
# split1_train_score                                    0.626471
# split2_train_score                                    0.627566
# split3_train_score                                    0.627566
# split4_train_score                                    0.625731
# mean_train_score                                      0.626761
# std_train_score                                    0.000710716
#
#                                                              5   \
# mean_fit_time                                             0.011
# std_fit_time                                        1.90735e-07
# mean_score_time                                      0.00220003
# std_score_time                                      0.000399995
# param_C                                                   0.001
# param_gamma                                                 100
# param_kernel                                                rbf
# params              {'C': 0.001, 'gamma': 100, 'kernel': 'rbf'}
# split0_test_score                                      0.627907
# split1_test_score                                      0.627907
# split2_test_score                                      0.623529
# split3_test_score                                      0.623529
# split4_test_score                                      0.630952
# mean_test_score                                        0.626761
# std_test_score                                       0.00285688
# rank_test_score                                              12
# split0_train_score                                     0.626471
# split1_train_score                                     0.626471
# split2_train_score                                     0.627566
# split3_train_score                                     0.627566
# split4_train_score                                     0.625731
# mean_train_score                                       0.626761
# std_train_score                                     0.000710716
#
#                                                               6   \
# mean_fit_time                                         0.00640001
# std_fit_time                                         0.000489862
# mean_score_time                                       0.00160003
# std_score_time                                       0.000489785
# param_C                                                     0.01
# param_gamma                                                0.001
# param_kernel                                                 rbf
# params              {'C': 0.01, 'gamma': 0.001, 'kernel': 'rbf'}
# split0_test_score                                       0.627907
# split1_test_score                                       0.627907
# split2_test_score                                       0.623529
# split3_test_score                                       0.623529
# split4_test_score                                       0.630952
# mean_test_score                                         0.626761
# std_test_score                                        0.00285688
# rank_test_score                                               12
# split0_train_score                                      0.626471
# split1_train_score                                      0.626471
# split2_train_score                                      0.627566
# split3_train_score                                      0.627566
# split4_train_score                                      0.625731
# mean_train_score                                        0.626761
# std_train_score                                      0.000710716
#
#                                                              7   \
# mean_fit_time                                        0.00999994
# std_fit_time                                        1.78416e-07
# mean_score_time                                      0.00220003
# std_score_time                                      0.000399876
# param_C                                                    0.01
# param_gamma                                                0.01
# param_kernel                                                rbf
# params              {'C': 0.01, 'gamma': 0.01, 'kernel': 'rbf'}
# split0_test_score                                      0.627907
# split1_test_score                                      0.627907
# split2_test_score                                      0.623529
# split3_test_score                                      0.623529
# split4_test_score                                      0.630952
# mean_test_score                                        0.626761
# std_test_score                                       0.00285688
# rank_test_score                                              12
# split0_train_score                                     0.626471
# split1_train_score                                     0.626471
# split2_train_score                                     0.627566
# split3_train_score                                     0.627566
# split4_train_score                                     0.625731
# mean_train_score                                       0.626761
# std_train_score                                     0.000710716
#
#                                                             8   \
# mean_fit_time                                            0.011
# std_fit_time                                       1.78416e-07
# mean_score_time                                     0.00260015
# std_score_time                                      0.00048994
# param_C                                                   0.01
# param_gamma                                                0.1
# param_kernel                                               rbf
# params              {'C': 0.01, 'gamma': 0.1, 'kernel': 'rbf'}
# split0_test_score                                     0.627907
# split1_test_score                                     0.627907
# split2_test_score                                     0.623529
# split3_test_score                                     0.623529
# split4_test_score                                     0.630952
# mean_test_score                                       0.626761
# std_test_score                                      0.00285688
# rank_test_score                                             12
# split0_train_score                                    0.626471
# split1_train_score                                    0.626471
# split2_train_score                                    0.627566
# split3_train_score                                    0.627566
# split4_train_score                                    0.625731
# mean_train_score                                      0.626761
# std_train_score                                    0.000710716
#
#                                                           9   \
# mean_fit_time                                      0.0110001
# std_fit_time                                     1.16801e-07
# mean_score_time                                   0.00259991
# std_score_time                                    0.00048994
# param_C                                                 0.01
# param_gamma                                                1
# param_kernel                                             rbf
# params              {'C': 0.01, 'gamma': 1, 'kernel': 'rbf'}
# split0_test_score                                   0.627907
# split1_test_score                                   0.627907
# split2_test_score                                   0.623529
# split3_test_score                                   0.623529
# split4_test_score                                   0.630952
# mean_test_score                                     0.626761
# std_test_score                                    0.00285688
# rank_test_score                                           12
# split0_train_score                                  0.626471
# split1_train_score                                  0.626471
# split2_train_score                                  0.627566
# split3_train_score                                  0.627566
# split4_train_score                                  0.625731
# mean_train_score                                    0.626761
# std_train_score                                  0.000710716
#
#                                  ...                \
# mean_fit_time                    ...
# std_fit_time                     ...
# mean_score_time                  ...
# std_score_time                   ...
# param_C                          ...
# param_gamma                      ...
# param_kernel                     ...
# params                           ...
# split0_test_score                ...
# split1_test_score                ...
# split2_test_score                ...
# split3_test_score                ...
# split4_test_score                ...
# mean_test_score                  ...
# std_test_score                   ...
# rank_test_score                  ...
# split0_train_score               ...
# split1_train_score               ...
# split2_train_score               ...
# split3_train_score               ...
# split4_train_score               ...
# mean_train_score                 ...
# std_train_score                  ...
#
#                                                            32  \
# mean_fit_time                                       0.0114001
# std_fit_time                                      0.000489804
# mean_score_time                                     0.0026001
# std_score_time                                    0.000489804
# param_C                                                   100
# param_gamma                                               0.1
# param_kernel                                              rbf
# params              {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
# split0_test_score                                    0.627907
# split1_test_score                                    0.627907
# split2_test_score                                    0.623529
# split3_test_score                                    0.623529
# split4_test_score                                    0.630952
# mean_test_score                                      0.626761
# std_test_score                                     0.00285688
# rank_test_score                                            12
# split0_train_score                                          1
# split1_train_score                                          1
# split2_train_score                                          1
# split3_train_score                                          1
# split4_train_score                                          1
# mean_train_score                                            1
# std_train_score                                             0
#
#                                                          33  \
# mean_fit_time                                        0.0116
# std_fit_time                                    0.000489843
# mean_score_time                                  0.00280004
# std_score_time                                  0.000399971
# param_C                                                 100
# param_gamma                                               1
# param_kernel                                            rbf
# params              {'C': 100, 'gamma': 1, 'kernel': 'rbf'}
# split0_test_score                                  0.627907
# split1_test_score                                  0.627907
# split2_test_score                                  0.623529
# split3_test_score                                  0.623529
# split4_test_score                                  0.630952
# mean_test_score                                    0.626761
# std_test_score                                   0.00285688
# rank_test_score                                          12
# split0_train_score                                        1
# split1_train_score                                        1
# split2_train_score                                        1
# split3_train_score                                        1
# split4_train_score                                        1
# mean_train_score                                          1
# std_train_score                                           0
#
#                                                           34  \
# mean_fit_time                                         0.0118
# std_fit_time                                     0.000400043
# mean_score_time                                   0.00239987
# std_score_time                                   0.000489921
# param_C                                                  100
# param_gamma                                               10
# param_kernel                                             rbf
# params              {'C': 100, 'gamma': 10, 'kernel': 'rbf'}
# split0_test_score                                   0.627907
# split1_test_score                                   0.627907
# split2_test_score                                   0.623529
# split3_test_score                                   0.623529
# split4_test_score                                   0.630952
# mean_test_score                                     0.626761
# std_test_score                                    0.00285688
# rank_test_score                                           12
# split0_train_score                                         1
# split1_train_score                                         1
# split2_train_score                                         1
# split3_train_score                                         1
# split4_train_score                                         1
# mean_train_score                                           1
# std_train_score                                            0
#
#                                                            35  \
# mean_fit_time                                          0.0118
# std_fit_time                                      0.000400043
# mean_score_time                                    0.00260015
# std_score_time                                     0.00048994
# param_C                                                   100
# param_gamma                                               100
# param_kernel                                              rbf
# params              {'C': 100, 'gamma': 100, 'kernel': 'rbf'}
# split0_test_score                                    0.627907
# split1_test_score                                    0.627907
# split2_test_score                                    0.623529
# split3_test_score                                    0.623529
# split4_test_score                                    0.630952
# mean_test_score                                      0.626761
# std_test_score                                     0.00285688
# rank_test_score                                            12
# split0_train_score                                          1
# split1_train_score                                          1
# split2_train_score                                          1
# split3_train_score                                          1
# split4_train_score                                          1
# mean_train_score                                            1
# std_train_score                                             0
#
#                                                   36  \
# mean_fit_time                             0.00319986
# std_fit_time                             0.000400162
# mean_score_time                                    0
# std_score_time                                     0
# param_C                                        0.001
# param_gamma                                      NaN
# param_kernel                                  linear
# params              {'C': 0.001, 'kernel': 'linear'}
# split0_test_score                           0.976744
# split1_test_score                           0.895349
# split2_test_score                           0.917647
# split3_test_score                           0.964706
# split4_test_score                           0.964286
# mean_test_score                             0.943662
# std_test_score                             0.0316137
# rank_test_score                                    6
# split0_train_score                              0.95
# split1_train_score                          0.967647
# split2_train_score                          0.958944
# split3_train_score                          0.944282
# split4_train_score                          0.953216
# mean_train_score                            0.954818
# std_train_score                           0.00798006
#
#                                                  37  \
# mean_fit_time                            0.00859995
# std_fit_time                             0.00508316
# mean_score_time                         0.000199986
# std_score_time                          0.000399971
# param_C                                        0.01
# param_gamma                                     NaN
# param_kernel                                 linear
# params              {'C': 0.01, 'kernel': 'linear'}
# split0_test_score                          0.976744
# split1_test_score                          0.930233
# split2_test_score                          0.917647
# split3_test_score                          0.976471
# split4_test_score                          0.964286
# mean_test_score                            0.953052
# std_test_score                            0.0245534
# rank_test_score                                   3
# split0_train_score                         0.958824
# split1_train_score                         0.961765
# split2_train_score                         0.970674
# split3_train_score                         0.950147
# split4_train_score                         0.959064
# mean_train_score                           0.960095
# std_train_score                          0.00657818
#
#                                                 38  \
# mean_fit_time                               0.0834
# std_fit_time                             0.0358418
# mean_score_time                        0.000200033
# std_score_time                         0.000400066
# param_C                                        0.1
# param_gamma                                    NaN
# param_kernel                                linear
# params              {'C': 0.1, 'kernel': 'linear'}
# split0_test_score                         0.976744
# split1_test_score                         0.930233
# split2_test_score                         0.929412
# split3_test_score                         0.976471
# split4_test_score                         0.964286
# mean_test_score                           0.955399
# std_test_score                           0.0214186
# rank_test_score                                  2
# split0_train_score                        0.961765
# split1_train_score                        0.961765
# split2_train_score                         0.97654
# split3_train_score                        0.964809
# split4_train_score                        0.964912
# mean_train_score                          0.965958
# std_train_score                         0.00546901
#
#                                               39  \
# mean_fit_time                             0.5662
# std_fit_time                            0.262343
# mean_score_time                                0
# std_score_time                                 0
# param_C                                        1
# param_gamma                                  NaN
# param_kernel                              linear
# params              {'C': 1, 'kernel': 'linear'}
# split0_test_score                       0.988372
# split1_test_score                       0.953488
# split2_test_score                       0.917647
# split3_test_score                       0.976471
# split4_test_score                       0.964286
# mean_test_score                         0.960094
# std_test_score                         0.0242223
# rank_test_score                                1
# split0_train_score                      0.967647
# split1_train_score                      0.964706
# split2_train_score                      0.985337
# split3_train_score                      0.964809
# split4_train_score                      0.973684
# mean_train_score                        0.971237
# std_train_score                       0.00776741
#
#                                                40  \
# mean_fit_time                              2.8724
# std_fit_time                              1.61234
# mean_score_time                       0.000400019
# std_score_time                        0.000489921
# param_C                                        10
# param_gamma                                   NaN
# param_kernel                               linear
# params              {'C': 10, 'kernel': 'linear'}
# split0_test_score                        0.965116
# split1_test_score                        0.930233
# split2_test_score                        0.905882
# split3_test_score                        0.964706
# split4_test_score                        0.964286
# mean_test_score                          0.946009
# std_test_score                          0.0241006
# rank_test_score                                 5
# split0_train_score                       0.967647
# split1_train_score                       0.967647
# split2_train_score                       0.982405
# split3_train_score                       0.973607
# split4_train_score                        0.97076
# mean_train_score                         0.972413
# std_train_score                        0.00546662
#
#                                                 41
# mean_fit_time                               5.2922
# std_fit_time                               2.31979
# mean_score_time                        0.000600052
# std_score_time                          0.00048994
# param_C                                        100
# param_gamma                                    NaN
# param_kernel                                linear
# params              {'C': 100, 'kernel': 'linear'}
# split0_test_score                         0.953488
# split1_test_score                         0.953488
# split2_test_score                         0.917647
# split3_test_score                         0.964706
# split4_test_score                          0.97619
# mean_test_score                           0.953052
# std_test_score                           0.0195668
# rank_test_score                                  3
# split0_train_score                        0.961765
# split1_train_score                        0.970588
# split2_train_score                        0.973607
# split3_train_score                        0.964809
# split4_train_score                        0.976608
# mean_train_score                          0.969476
# std_train_score                         0.00548474
#
# [23 rows x 42 columns]

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score

iris = load_iris()
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, random_state=0)

param_grid = {'C' : grid_list,
             'gamma' : grid_list}
scores = cross_val_score(GridSearchCV(SVC(),iid=False, param_grid=param_grid, cv=5),
                        X_test, y_test, cv=5)
print("교차 검증 점수 :", scores)
print("교차 검증 평균 점수 :", scores.mean())
# Out:
# 교차 검증 점수 : [1.         1.         0.875      0.85714286 0.83333333]
# 교차 검증 평균 점수 : 0.9130952380952382
