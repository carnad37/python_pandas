# %%
import pandas as pd
import numpy as np
ss_df = pd.read_csv("./subjectScore.csv")
ss_df
# Out:
#       name  english  math  science  Biology  music  history
# 0     john       90    80       70      100    100       40
# 1     mary       60    70       80       70     90       90
# 2      tom       50    40       80       70     60       80
# 3    brown      100    80       60       70     70       80
# 4   snoopy       80    70       80       60     80       90
# 5     dori       90    60       90       80     90       80
# 6  michale       80    70       90       60     80       70
# 7    pooni       70    60       80       90     80       60

# %%
ss_df[(ss_df['name'] == 'mary')|(ss_df['name'] == 'john')|(ss_df['name'] == 'tom')]
# Out:
#    name  english  math  science  Biology  music  history
# 0  john       90    80       70      100    100       40
# 1  mary       60    70       80       70     90       90
# 2   tom       50    40       80       70     60       80

# %%
ss_df[ss_df['english'] > 90]
# Out:
#     name  english  math  science  Biology  music  history
# 3  brown      100    80       60       70     70       80

# %%
ss_df[ss_df['name'].map(lambda x: x in ['mary', 'john', 'tom'])]
# Out:
#    name  english  math  science  Biology  music  history
# 0  john       90    80       70      100    100       40
# 1  mary       60    70       80       70     90       90
# 2   tom       50    40       80       70     60       80

# %%
ss_df[[ss_df['english'], ss_df['math']].map(lambda x: (x[0] > 60) & (y[1] > 60))]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-23abd52e3c1c> in <module>
# ----> 1 ss_df[[ss_df['english'], ss_df['math']].map(lambda x: (x[0] > 60) & (y[1] > 60))]
#
# AttributeError: 'list' object has no attribute 'map'

# %%
ss_df[(ss_df['english'] > 90) & (ss_df['math'] > 70)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-dafd713f1629> in <module>
# ----> 1 ss_df[(100 > 90) & (200 > 70)]
#
# ...

# %%
ss_df[True]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-efe620062d52> in <module>
# ----> 1 ss_df[True]
#
# ...

# %%
ss_df[['english', 'math']]
# Out:
#    english  math
# 0       90    80
# 1       60    70
# 2       50    40
# 3      100    80
# 4       80    70
# 5       90    60
# 6       80    70
# 7       70    60

# %%
ss_df.loc[[1,2,3],['name', 'music', 'history']]
# Out:
#     name  music  history
# 1   mary     90       90
# 2    tom     60       80
# 3  brown     70       80

# %%
ss_df['eng_pass'] = ss_df['english'] >= 90
ss_df
# Out:
#       name  english  math  science  Biology  music  history  eng_pass
# 0     john       90    80       70      100    100       40      True
# 1     mary       60    70       80       70     90       90     False
# 2      tom       50    40       80       70     60       80     False
# 3    brown      100    80       60       70     70       80      True
# 4   snoopy       80    70       80       60     80       90     False
# 5     dori       90    60       90       80     90       80      True
# 6  michale       80    70       90       60     80       70     False
# 7    pooni       70    60       80       90     80       60     False

# %%
ss_df['name'][ss_df['english'] >= 70]
# Out:
# 0       john
# 3      brown
# 4     snoopy
# 5       dori
# 6    michale
# 7      pooni
# Name: name, dtype: object

# %%
ss_df.english.mean()
# Out:
# 77.5

# %%
# Out:
# english    620
# math       530
# science    630
# Biology    600
# music      650
# history    590
# dtype: int64

# %%
ss_df.loc[len(ss_df.index)] = ss_df.drop('name', axis=1).sum(axis=0)
ss_df
# Out:
#       name  english   math  science  Biology  music  history
# 0     john     90.0   80.0     70.0    100.0  100.0     40.0
# 1     mary     60.0   70.0     80.0     70.0   90.0     90.0
# 2      tom     50.0   40.0     80.0     70.0   60.0     80.0
# 3    brown    100.0   80.0     60.0     70.0   70.0     80.0
# 4   snoopy     80.0   70.0     80.0     60.0   80.0     90.0
# 5     dori     90.0   60.0     90.0     80.0   90.0     80.0
# 6  michale     80.0   70.0     90.0     60.0   80.0     70.0
# 7    pooni     70.0   60.0     80.0     90.0   80.0     60.0
# 8      NaN    620.0  530.0    630.0    600.0  650.0    590.0

# %%
ss_df["name"][len(ss_df.index)]
# Out:
# 'sum'

# %%
ss_df
# Out:
#       name  english   math  science  Biology  music  history
# 0     john     90.0   80.0     70.0    100.0  100.0     40.0
# 1     mary     60.0   70.0     80.0     70.0   90.0     90.0
# 2      tom     50.0   40.0     80.0     70.0   60.0     80.0
# 3    brown    100.0   80.0     60.0     70.0   70.0     80.0
# 4   snoopy     80.0   70.0     80.0     60.0   80.0     90.0
# 5     dori     90.0   60.0     90.0     80.0   90.0     80.0
# 6  michale     80.0   70.0     90.0     60.0   80.0     70.0
# 7    pooni     70.0   60.0     80.0     90.0   80.0     60.0
# 8      avg    620.0  530.0    630.0    600.0  650.0    590.0
